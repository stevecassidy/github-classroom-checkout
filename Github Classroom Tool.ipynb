# %% [markdown]
# # Github Classroom Workshop Checkout Tool
#
# This notebook provides a tool to checkout all of the student github repositories for one or more workshops.  It
# assumes that you have password-less checkout configured for github using a public/private key pair.
#
#
# It requires two files to drive the process:
# * The gradebook downloaded from iLearn as a CSV file (in gradebook, choose _Export_ and then choose _Plain Text File_.
# * The Github Classroom roster, downloaded from Github Classroom
#
# These should be saved in the same directory as this notebook.
#
# The code below will then checkout each github repository and store it in a directory named for the workshop and a subdirectory named for the student ID.  Eg. `submissions/Workshop_1|FRI|01:00PM|C13/46457771`.  If you run this a second time, and the repository already exists, it will just do a pull from Github to update the repository with more recent work.
#
# Once either the checkout or pull is complete, the script runs `nbconvert` on all notebook files in the repository to convert them to HTML.  It then outputs a list of links to the HTML files in the notebook below.  You can click on each link and it will be opened in a new window.   This should be quicker than opening the notebook file itself.
#
# I've included a list of all workshop names just for reference, choose your workshops from this list and update the config.

# %%
from classroom import process
from IPython.core.display import HTML

all_workshops = ['Workshop_1|TUE|01:00PM|C02', 
                 'Workshop_1|TUE|11:00AM|C01', 
                 'Workshop_1|THU|09:00AM|C06', 
                 'Workshop_1|FRI|01:00PM|C13', 
                 'Workshop_1|FRI|11:00AM|C12', 
                 'Workshop_1|THU|01:00PM|C08', 
                 'Workshop_1|FRI|03:00PM|C14', 
                 'Workshop_1|WED|01:00PM|C03', 
                 'Workshop_1|TUE|06:00PM|C01', 
                 'Workshop_1|TUE|09:00AM|C17', 
                 'Workshop_1|THU|05:00PM|C10', 
                 'Workshop_1|MON|06:00PM|C16', 
                 'Workshop_1|THU|11:00AM|C07', 
                 'Workshop_1|WED|05:00PM|C05', 
                 'Workshop_1|TUE|06:00PM|C04', 
                 'Workshop_1|MON|04:00PM|C15', 
                 'Workshop_1|FRI|09:00AM|C11'
                ]


# update config as needed
config = {
    'github-roster': 'classroom_roster.csv',
    'ilearn-csv': 'COMP2200_SHFYR_2021_ALL_Uwith COMP6200 Co-badged Grades-20210731_0912-comma_separated.csv',
    "github-id-pattern": "\\d+",
    "key-field": "id",
    'classroom': "git@github.com:MQCOMP2200-S2-2021",
    'assignment': "practical-week-1",
    'outdir': 'submissions-2200',
    'workshops': ['Workshop_1|FRI|01:00PM|C13'],
    'nbconvert': True,
    'report': False
}


HTML(process(config))
# Out:
# ['Workshop_1|TUE|01:00PM|C02', 'Workshop_1|TUE|11:00AM|C01', 'Workshop_1|THU|09:00AM|C06', 'Workshop_1|FRI|01:00PM|C13', 'Workshop_1|FRI|11:00AM|C12', 'Workshop_1|THU|01:00PM|C08', 'Workshop_1|FRI|03:00PM|C14', 'Workshop_1|WED|01:00PM|C03', 'Workshop_1|TUE|06:00PM|C01', 'Workshop_1|TUE|09:00AM|C17', 'Workshop_1|THU|05:00PM|C10', 'Workshop_1|MON|06:00PM|C16', 'Workshop_1|THU|11:00AM|C07', 'Workshop_1|WED|05:00PM|C05', 'Workshop_1|TUE|06:00PM|C04', 'Workshop_1|MON|04:00PM|C15', 'Workshop_1|FRI|09:00AM|C11']
# Extra names in Github Classroom roster
# 44478925
# 111111
# 46348492
# 46171886
# 47156910
# 45875758
# 46576746
# 46123601
# 47162015
# 45280223
# 47082496
# 46386106
# 46366784
# 46981101
# 46599851
# 46570306
# 45239231
# 45782334
# 45111650
# 46182608
#
# Students not in Github Classroom Roster
# Add these to the roster to associate with student github accounts
# thuseevan.nareshkumar@students.mq.edu.au
# tran-chau-ngoc.tran-chau-ng@students.mq.edu.au
# erik.horvath@students.mq.edu.au
# md-fareeg-hasan.faisal@students.mq.edu.au
# muhammad-mustafa-nadeem.kha@students.mq.edu.au
# gleb.kovalev@students.mq.edu.au
# muhammad.khan4@students.mq.edu.au
# zoljargal.byambadorj@students.mq.edu.au
# ziheng.liu1@students.mq.edu.au
# arjun.kaul@students.mq.edu.au
# jiuding.liu@students.mq.edu.au
# supriya.baweja@students.mq.edu.au
# matthew.westerlund@students.mq.edu.au
# blake.goss@students.mq.edu.au
# deepesh.khanal@students.mq.edu.au
# nicholas.palmer3@students.mq.edu.au
#
# These students have no github account yet
# shaun.buss@students.mq.edu.au
# carlo.fares@students.mq.edu.au
# ryan.lam1@students.mq.edu.au
# reddhishri.chakma@students.mq.edu.au
# marcus.fernandez1@students.mq.edu.au
# wenkang.guo@students.mq.edu.au
# benjamin.mackie@students.mq.edu.au
# yunfei.xiao@students.mq.edu.au
# raisa.mostafa@students.mq.edu.au
# tahsin.hossain@students.mq.edu.au
# henda.guo@students.mq.edu.au
# simon.attalla@students.mq.edu.au
# adam.thomas3@students.mq.edu.au
# charishma.ummadisetti@students.mq.edu.au
# claire.eyaru@students.mq.edu.au
# mehak.shekhawat@students.mq.edu.au
# krispaulbabu.krispaulbabu@students.mq.edu.au
# zawaar.shah@students.mq.edu.au
# nenor.oshana@students.mq.edu.au
# diviya.raman@students.mq.edu.au
# liam.gornall@students.mq.edu.au
# thomas.haes@students.mq.edu.au
# mohammed-fardeen.mohammed-f@students.mq.edu.au
# ruobing.wang1@students.mq.edu.au
# yonathan.ferdman@students.mq.edu.au
# tom.buckley@students.mq.edu.au
# fangzhou.liu@students.mq.edu.au
# joshua.falanga@students.mq.edu.au
# muammer.eyvaz@students.mq.edu.au
# aarushi.chaudhary@students.mq.edu.au
# luca.wormald@students.mq.edu.au
# farjana.setu@students.mq.edu.au
# anton.zhang@students.mq.edu.au
# kiran.kumar@students.mq.edu.au
# shafeen.sharif@students.mq.edu.au
# srijan.nayyar@students.mq.edu.au
# chhade.alasbar@students.mq.edu.au
# prachi.prachi@students.mq.edu.au
# natalie.chhai@students.mq.edu.au
# jordan.batten@students.mq.edu.au
# raj.singh@students.mq.edu.au
# najibullah.rezai@students.mq.edu.au
# alexandra.ellison@students.mq.edu.au
# bhumik-birenkumar.shah@students.mq.edu.au
# michael.szczerba@students.mq.edu.au
# mikhail.pavlov@students.mq.edu.au
# bailey.paton@students.mq.edu.au
# hannah.arain@students.mq.edu.au
# dylan.lay@students.mq.edu.au
# sabir.khagi@students.mq.edu.au
# nicki.daghighi@students.mq.edu.au
# antas.sareen@students.mq.edu.au
# nathan.lewis1@students.mq.edu.au
# allan-kudzai.mawande@students.mq.edu.au
# juan.cerillo@students.mq.edu.au
# lachlan.woodhill@students.mq.edu.au
# ishtiyaq.khan@students.mq.edu.au
# anna.le6@students.mq.edu.au
# he.bai1@students.mq.edu.au
# harry.pham1@students.mq.edu.au
# richard.tran2@students.mq.edu.au
# lovepreet.sahota@students.mq.edu.au
# aditya.deshpande@students.mq.edu.au
# ....................
